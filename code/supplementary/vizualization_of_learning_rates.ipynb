# %% [markdown]
# Notebook examining error in the training and validation sets for the best five models. ***Note that these models were re-trained to produce these figures so they may not exactly match the results presented in the paper.*** The graphs for the five final models presented in the paper can be found in the main notebook, `gpa.ipynb`.

# %%
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (6,4.5)
#%config InlineBackend.figure_format = 'retina' # Uncomment if using a retina display
plt.rc('pdf', fonttype=42)
plt.rcParams['ps.useafm'] = True
plt.rcParams['pdf.use14corefonts'] = True
#plt.rcParams['text.usetex'] = True # Uncomment if LaTeX installed to render plots in LaTeX
plt.rcParams['font.serif'] = 'Times'
plt.rcParams['font.family'] = 'serif'

# %%
histories = pickle.load(open('../output/model_histories.p', 'rb'))

# %%
histories
# Out:
# {'model_1': {'val_loss': [3.3399103613460763,
#    2.0256653031180885,
#    0.3073396234652575,
#    0.5723660178745494,
#    0.9405577987783096,
#    1.8168666486179128,
#    0.5329768343532787,
#    0.9223291803808773,
#    1.2181899763556088,
#    0.5052500434482798,
#    1.3087216983121983,
#    0.35790845744750077,
#    0.3128719040926765,
#    1.1406779951207777,
#    0.4057245282565846,
#    0.3098813337438247,
#    0.40977146835888134,
#    0.6346324225734262],
#   'loss': [260.57051613645734,
#    34.58935575665168,
#    23.44213816804706,
#    23.891180596261655,
#    30.992028398333854,
#    32.43998601301661,
#    23.16934166314467,
#    20.209880954814405,
#    18.42970515197178,
#    15.16408453347548,
#    12.110745483974242,
#    11.154019607687896,
#    8.816357878019225,
#    8.088360336591613,
#    7.605782229945345,
#    6.611098887785426,
#    7.0998284501849485,
#    5.077216134881073]},
#  'model_2': {'val_loss': [0.24153771961436551,
#    0.21685920722344343,
# ...

# %% [markdown]
# Graphs with all epochs included.

# %%
for i, k in enumerate(list(histories.keys())): 
    plt.plot(list(range(1, len(histories[k]['loss'])+1)), histories[k]['loss'])
    plt.plot(list(range(1, len(histories[k]['loss'])+1)), histories[k]['val_loss'])
    plt.title('Model '+str(i+1)+': Mean squared error by training epoch')
    plt.ylabel('MSE')
    plt.xlabel('Epoch')
    plt.legend(['Training data', 'Validation data'], loc='upper left')
    plt.show()
# Out:
# /opt/anaconda/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Graphs with truncated y-axis due to removal of first 5 epochs:

# %%
for i, k in enumerate(list(histories.keys())): 
    plt.plot(list(range(5, len(histories[k]['loss'][5:])+5)), histories[k]['loss'][5:])
    plt.plot(list(range(5, len(histories[k]['loss'][5:])+5)), histories[k]['val_loss'][5:])
    plt.title('Model '+str(i+1)+': Mean squared error by training epoch')
    plt.ylabel('MSE')
    plt.xlabel('Epoch')
    plt.legend(['Training data', 'Validation data'], loc='upper left')
    plt.xlim(5, len(histories[k]['loss'])-1)
    plt.savefig('training_graph_'+str(i+1)+'.pdf')
    plt.show()
